# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2  Python-3.10.14 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 159.9/199.5 GB disk)

# %%
model = YOLO('C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/weights/best.pt')

# %%
metrics = model.val(data = 'C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/helmet_2.yaml', save_txt = True)  # no arguments needed, dataset and settings remembered
   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.2  Python-3.10.14 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# val: Scanning C:\Users\ASUS\Desktop\helmet detection\helmet_dataset\labels\val.cache... 500 images, 0 backgrounds, 0 co
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 32/32 [03:30
#                    all        500       2607      0.919      0.514      0.579      0.359
#                 helmet        500       1923      0.927      0.766      0.882      0.546
#                   head        500        613      0.831      0.777      0.847      0.529
#                 person        500         71          1          0    0.00674     0.0027
# Speed: 1.4ms preprocess, 370.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to C:\Users\ASUS\runs\detect\val6

# %%
metrics = model.val(data = 'C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/helmet_2.yaml', save_txt = True, split = 'train', save_json = True)
# Out:
# Ultralytics YOLOv8.2.2  Python-3.10.14 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# val: Scanning C:\Users\ASUS\Desktop\helmet detection\helmet_dataset\labels\train... 4000 images, 0 backgrounds, 0 corru
# val: New cache created: C:\Users\ASUS\Desktop\helmet detection\helmet_dataset\labels\train.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 250/250 [28:
#                    all       4000      20302      0.918       0.52      0.579      0.361
#                 helmet       4000      15151       0.93      0.791      0.899      0.563
#                   head       4000       4532      0.824      0.767      0.831      0.516
#                 person       4000        619          1          0    0.00819     0.0027
# Speed: 1.6ms preprocess, 376.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Saving C:\Users\ASUS\runs\detect\val9\predictions.json...
# ...

# %%
metrics
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x0000024EAADCF550>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
# ...

# %%
import json

with open('C:/Users/ASUS/runs/detect/val7/predictions.json') as f:
   data_json = json.load(f)

# %%
data_json
# Out:
# [{'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [224.46, 88.352, 67.552, 85.204],
#   'score': 0.83011},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [228.227, 0.0, 63.671, 47.353],
#   'score': 0.823},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [341.287, 122.142, 54.44, 62.37],
#   'score': 0.80323},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [63.414, 79.76, 96.917, 93.996],
#   'score': 0.78143},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [69.709, 78.771, 67.753, 91.194],
#   'score': 0.75686},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [49.56, 0.673, 113.749, 58.739],
#   'score': 0.67409},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 1,
#   'bbox': [337.644, 0.0, 61.219, 17.811],
#   'score': 0.31449},
#  {'image_id': 'hard_hat_workers324',
#   'category_id': 0,
# ...

# %% [markdown]
# # update yaml file

# %%
data = 'C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/helmet.yaml'

# %%
import yaml

# %%
with open(data, 'r') as file:
    f = yaml.safe_load(file)

# %%
f['path']
# Out:
# '/content/gdrive/MyDrive/yolov8/helmet_data/helmet_dataset'

# %%
f['path']= 'C:/Users/ASUS/Desktop/helmet detection/helmet_dataset'

# %%
f
# Out:
# {'path': 'C:/Users/ASUS/Desktop/helmet detection/helmet_dataset',
#  'train': 'images/train',
#  'val': 'images/val',
#  'test': 'images/test',
#  'names': ['helmet', 'head', 'person']}

# %%
ff = """
{'path': 'C:/Users/ASUS/Desktop/helmet detection/helmet_dataset',
 'train': 'images/train',
 'val': 'images/val',
 'test': 'images/test',
 'names': ['helmet', 'head', 'person']}
 """

# %%
helmet_2 = yaml.safe_load(ff)

with open('C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/helmet_2.yaml', 'w') as file:
    yaml.dump(helmet_2, file)

# %%
with open('C:/Users/ASUS/Desktop/helmet detection/yolov8_helmet_gpu/helmet_2.yaml', 'r') as file:
    fff = yaml.safe_load(file)

# %%
fff
# Out:
# {'names': ['helmet', 'head', 'person'],
#  'path': 'C:/Users/ASUS/Desktop/helmet detection/helmet_dataset',
#  'test': 'images/test',
#  'train': 'images/train',
#  'val': 'images/val'}
